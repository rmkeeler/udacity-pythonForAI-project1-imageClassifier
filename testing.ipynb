# %%
# Imports python modules
from time import time, sleep

# Imports print functions that check the lab
from print_functions_for_lab_checks import *

# Imports functions created for this program
from get_input_args import get_input_args
from get_pet_labels import get_pet_labels
from classify_images import classify_images
from adjust_results4_isadog import adjust_results4_isadog
from calculates_results_stats import calculates_results_stats
from print_results import print_results
# Out:
# C:\users\keele\onedrive\learning\Udacity Courses\202403 - Python for AI\env\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\users\keele\onedrive\learning\Udacity Courses\202403 - Python for AI\env\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# C:\users\keele\onedrive\learning\Udacity Courses\202403 - Python for AI\env\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# C:\users\keele\onedrive\learning\Udacity Courses\202403 - Python for AI\env\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
files_dir = 'pet_images'
arch = 'vgg'
dogfile = 'dognames.txt'
results = get_pet_labels(files_dir)

# %%
results
# Out:
# {'Basenji_00963.jpg': ['basenji'],
#  'Basenji_00974.jpg': ['basenji'],
#  'Basset_hound_01034.jpg': ['basset hound'],
#  'Beagle_01125.jpg': ['beagle'],
#  'Beagle_01141.jpg': ['beagle'],
#  'Beagle_01170.jpg': ['beagle'],
#  'Boston_terrier_02259.jpg': ['boston terrier'],
#  'Boston_terrier_02285.jpg': ['boston terrier'],
#  'Boston_terrier_02303.jpg': ['boston terrier'],
#  'Boxer_02426.jpg': ['boxer'],
#  'cat_01.jpg': ['cat'],
#  'cat_02.jpg': ['cat'],
#  'cat_07.jpg': ['cat'],
#  'Cocker_spaniel_03750.jpg': ['cocker spaniel'],
#  'Collie_03797.jpg': ['collie'],
#  'Dalmatian_04017.jpg': ['dalmatian'],
#  'Dalmatian_04037.jpg': ['dalmatian'],
#  'Dalmatian_04068.jpg': ['dalmatian'],
#  'fox_squirrel_01.jpg': ['fox squirrel'],
#  'gecko_02.jpg': ['gecko'],
#  'gecko_80.jpg': ['gecko'],
#  'German_shepherd_dog_04890.jpg': ['german shepherd dog'],
#  'German_shepherd_dog_04931.jpg': ['german shepherd dog'],
#  'German_shorthaired_pointer_04986.jpg': ['german shorthaired pointer'],
#  'Golden_retriever_05182.jpg': ['golden retriever'],
#  'Golden_retriever_05195.jpg': ['golden retriever'],
#  'Golden_retriever_05223.jpg': ['golden retriever'],
#  'Golden_retriever_05257.jpg': ['golden retriever'],
#  'Great_dane_05320.jpg': ['great dane'],
#  'great_horned_owl_02.jpg': ['great horned owl'],
#  'Great_pyrenees_05367.jpg': ['great pyrenees'],
#  'Great_pyrenees_05435.jpg': ['great pyrenees'],
#  'Miniature_schnauzer_06884.jpg': ['miniature schnauzer'],
#  'polar_bear_04.jpg': ['polar bear'],
#  'Poodle_07927.jpg': ['poodle'],
#  'Poodle_07956.jpg': ['poodle'],
#  'Rabbit_002.jpg': ['rabbit'],
#  'Saint_bernard_08010.jpg': ['saint bernard'],
#  'Saint_bernard_08036.jpg': ['saint bernard'],
#  'skunk_029.jpg': ['skunk']}

# %%
classify_images(files_dir, results, arch)
# Out:
# Checking image at pet_images/Basenji_00963.jpg
# basenji: ['basenji']: 1
# Checking image at pet_images/Basenji_00974.jpg
# basenji: ['basenji']: 1
# Checking image at pet_images/Basset_hound_01034.jpg
# basset hound: ['basset', 'basset hound']: 1
# Checking image at pet_images/Beagle_01125.jpg
# beagle: ['beagle']: 1
# Checking image at pet_images/Beagle_01141.jpg
# beagle: ['beagle']: 1
# Checking image at pet_images/Beagle_01170.jpg
# beagle: ['walker hound', 'walker foxhound']: 0
# Checking image at pet_images/Boston_terrier_02259.jpg
# boston terrier: ['boston bull', 'boston terrier']: 1
# Checking image at pet_images/Boston_terrier_02285.jpg
# boston terrier: ['boston bull', 'boston terrier']: 1
# Checking image at pet_images/Boston_terrier_02303.jpg
# boston terrier: ['boston bull', 'boston terrier']: 1
# Checking image at pet_images/Boxer_02426.jpg
# boxer: ['boxer']: 1
# Checking image at pet_images/cat_01.jpg
# cat: ['lynx']: 0
# Checking image at pet_images/cat_02.jpg
# cat: ['tabby', 'tabby cat', 'cat']: 1
# Checking image at pet_images/cat_07.jpg
# cat: ['egyptian cat', 'cat']: 1
# Checking image at pet_images/Cocker_spaniel_03750.jpg
# cocker spaniel: ['cocker spaniel', 'english cocker spaniel', 'cocker']: 1
# Checking image at pet_images/Collie_03797.jpg
# collie: ['collie']: 1
# Checking image at pet_images/Dalmatian_04017.jpg
# dalmatian: ['dalmatian', 'coach dog', 'carriage dog']: 1
# Checking image at pet_images/Dalmatian_04037.jpg
# dalmatian: ['dalmatian', 'coach dog', 'carriage dog']: 1
# Checking image at pet_images/Dalmatian_04068.jpg
# dalmatian: ['dalmatian', 'coach dog', 'carriage dog']: 1
# Checking image at pet_images/fox_squirrel_01.jpg
# fox squirrel: ['fox squirrel', 'eastern fox squirrel', 'sciurus niger']: 1
# Checking image at pet_images/gecko_02.jpg
# gecko: ['banded gecko', 'gecko']: 1
# Checking image at pet_images/gecko_80.jpg
# gecko: ['tailed frog', 'bell toad', 'ribbed toad', 'tailed toad', 'ascaphus trui']: 0
# Checking image at pet_images/German_shepherd_dog_04890.jpg
# german shepherd dog: ['german shepherd', 'german shepherd dog', 'german police dog', 'alsatian']: 1
# Checking image at pet_images/German_shepherd_dog_04931.jpg
# german shepherd dog: ['german shepherd', 'german shepherd dog', 'german police dog', 'alsatian']: 1
# Checking image at pet_images/German_shorthaired_pointer_04986.jpg
# german shorthaired pointer: ['german shorthaired pointer']: 1
# Checking image at pet_images/Golden_retriever_05182.jpg
# golden retriever: ['golden retriever']: 1
# Checking image at pet_images/Golden_retriever_05195.jpg
# golden retriever: ['golden retriever']: 1
# Checking image at pet_images/Golden_retriever_05223.jpg
# golden retriever: ['golden retriever']: 1
# Checking image at pet_images/Golden_retriever_05257.jpg
# golden retriever: ['golden retriever']: 1
# Checking image at pet_images/Great_dane_05320.jpg
# great dane: ['great dane']: 1
# Checking image at pet_images/great_horned_owl_02.jpg
# great horned owl: ['ruffed grouse', 'partridge', 'bonasa umbellus']: 0
# Checking image at pet_images/Great_pyrenees_05367.jpg
# great pyrenees: ['kuvasz']: 0
# Checking image at pet_images/Great_pyrenees_05435.jpg
# great pyrenees: ['great pyrenees']: 1
# Checking image at pet_images/Miniature_schnauzer_06884.jpg
# miniature schnauzer: ['miniature schnauzer']: 1
# Checking image at pet_images/polar_bear_04.jpg
# polar bear: ['ice bear', 'polar bear', 'ursus maritimus', 'thalarctos maritimus']: 1
# Checking image at pet_images/Poodle_07927.jpg
# poodle: ['standard poodle', 'poodle']: 1
# Checking image at pet_images/Poodle_07956.jpg
# poodle: ['standard poodle', 'poodle']: 1
# Checking image at pet_images/Rabbit_002.jpg
# rabbit: ['wood rabbit', 'cottontail', 'cottontail rabbit', 'rabbit']: 1
# Checking image at pet_images/Saint_bernard_08010.jpg
# saint bernard: ['saint bernard', 'st bernard']: 1
# Checking image at pet_images/Saint_bernard_08036.jpg
# saint bernard: ['saint bernard', 'st bernard']: 1
# Checking image at pet_images/skunk_029.jpg
# skunk: ['skunk', 'polecat', 'wood pussy']: 1

# %%
results
# Out:
# {'Basenji_00963.jpg': ['basenji', 'basenji', 1],
#  'Basenji_00974.jpg': ['basenji', 'basenji', 1],
#  'Basset_hound_01034.jpg': ['basset hound', 'basset, basset hound', 1],
#  'Beagle_01125.jpg': ['beagle', 'beagle', 1],
#  'Beagle_01141.jpg': ['beagle', 'beagle', 1],
#  'Beagle_01170.jpg': ['beagle', 'walker hound, walker foxhound', 0],
#  'Boston_terrier_02259.jpg': ['boston terrier',
#   'boston bull, boston terrier',
#   1],
#  'Boston_terrier_02285.jpg': ['boston terrier',
#   'boston bull, boston terrier',
#   1],
#  'Boston_terrier_02303.jpg': ['boston terrier',
#   'boston bull, boston terrier',
#   1],
#  'Boxer_02426.jpg': ['boxer', 'boxer', 1],
#  'cat_01.jpg': ['cat', 'lynx', 0],
#  'cat_02.jpg': ['cat', 'tabby, tabby cat, cat', 1],
#  'cat_07.jpg': ['cat', 'egyptian cat, cat', 1],
#  'Cocker_spaniel_03750.jpg': ['cocker spaniel',
#   'cocker spaniel, english cocker spaniel, cocker',
#   1],
#  'Collie_03797.jpg': ['collie', 'collie', 1],
#  'Dalmatian_04017.jpg': ['dalmatian', 'dalmatian, coach dog, carriage dog', 1],
#  'Dalmatian_04037.jpg': ['dalmatian', 'dalmatian, coach dog, carriage dog', 1],
#  'Dalmatian_04068.jpg': ['dalmatian', 'dalmatian, coach dog, carriage dog', 1],
#  'fox_squirrel_01.jpg': ['fox squirrel',
#   'fox squirrel, eastern fox squirrel, sciurus niger',
#   1],
#  'gecko_02.jpg': ['gecko', 'banded gecko, gecko', 1],
#  'gecko_80.jpg': ['gecko',
#   'tailed frog, bell toad, ribbed toad, tailed toad, ascaphus trui',
#   0],
#  'German_shepherd_dog_04890.jpg': ['german shepherd dog',
#   'german shepherd, german shepherd dog, german police dog, alsatian',
#   1],
#  'German_shepherd_dog_04931.jpg': ['german shepherd dog',
#   'german shepherd, german shepherd dog, german police dog, alsatian',
#   1],
#  'German_shorthaired_pointer_04986.jpg': ['german shorthaired pointer',
#   'german shorthaired pointer',
#   1],
#  'Golden_retriever_05182.jpg': ['golden retriever', 'golden retriever', 1],
#  'Golden_retriever_05195.jpg': ['golden retriever', 'golden retriever', 1],
#  'Golden_retriever_05223.jpg': ['golden retriever', 'golden retriever', 1],
#  'Golden_retriever_05257.jpg': ['golden retriever', 'golden retriever', 1],
#  'Great_dane_05320.jpg': ['great dane', 'great dane', 1],
#  'great_horned_owl_02.jpg': ['great horned owl',
#   'ruffed grouse, partridge, bonasa umbellus',
#   0],
#  'Great_pyrenees_05367.jpg': ['great pyrenees', 'kuvasz', 0],
#  'Great_pyrenees_05435.jpg': ['great pyrenees', 'great pyrenees', 1],
#  'Miniature_schnauzer_06884.jpg': ['miniature schnauzer',
#   'miniature schnauzer',
#   1],
#  'polar_bear_04.jpg': ['polar bear',
#   'ice bear, polar bear, ursus maritimus, thalarctos maritimus',
#   1],
#  'Poodle_07927.jpg': ['poodle', 'standard poodle, poodle', 1],
#  'Poodle_07956.jpg': ['poodle', 'standard poodle, poodle', 1],
#  'Rabbit_002.jpg': ['rabbit',
#   'wood rabbit, cottontail, cottontail rabbit, rabbit',
#   1],
#  'Saint_bernard_08010.jpg': ['saint bernard', 'saint bernard, st bernard', 1],
#  'Saint_bernard_08036.jpg': ['saint bernard', 'saint bernard, st bernard', 1],
#  'skunk_029.jpg': ['skunk', 'skunk, polecat, wood pussy', 1]}

# %%
adjust_results4_isadog(results, dogfile)
# Out:
# ['chihuahua', 'japanese spaniel', 'maltese dog', 'maltese terrier', 'maltese', 'pekinese', 'pekingese', 'peke', 'shih-tzu', 'blenheim spaniel', 'papillon', 'toy terrier', 'rhodesian ridgeback', 'afghan hound', 'afghan', 'basset', 'basset hound', 'beagle', 'bloodhound', 'sleuthhound', 'bluetick', 'black-and-tan coonhound', 'walker hound', 'walker foxhound', 'english foxhound', 'redbone', 'borzoi', 'russian wolfhound', 'irish wolfhound', 'italian greyhound', 'whippet', 'ibizan hound', 'ibizan podenco', 'norwegian elkhound', 'elkhound', 'otterhound', 'otter hound', 'saluki', 'gazelle hound', 'scottish deerhound', 'deerhound', 'weimaraner', 'staffordshire bullterrier', 'staffordshire bull terrier', 'american staffordshire terrier', 'staffordshire terrier', 'american pit bull terrier', 'pit bull terrier', 'bedlington terrier', 'border terrier', 'kerry blue terrier', 'irish terrier', 'norfolk terrier', 'norwich terrier', 'yorkshire terrier', 'wire-haired fox terrier', 'lakeland terrier', 'sealyham terrier', 'sealyham', 'airedale', 'airedale terrier', 'cairn', 'cairn terrier', 'australian terrier', 'dandie dinmont', 'dandie dinmont terrier', 'boston bull', 'boston terrier', 'miniature schnauzer', 'giant schnauzer', 'standard schnauzer', 'schnauzer', 'scotch terrier', 'scottish terrier', 'scottie', 'tibetan terrier', 'chrysanthemum dog', 'silky terrier', 'sydney silky', 'soft-coated wheaten terrier', 'west highland white terrier', 'lhasa', 'lhasa apso', 'flat-coated retriever', 'curly-coated retriever', 'golden retriever', 'labrador retriever', 'chesapeake bay retriever', 'german shorthaired pointer', 'vizsla', 'hungarian pointer', 'english setter', 'irish setter', 'red setter', 'gordon setter', 'brittany spaniel', 'clumber', 'clumber spaniel', 'english springer', 'english springer spaniel', 'welsh springer spaniel', 'cocker spaniel', 'english cocker spaniel', 'cocker', 'sussex spaniel', 'irish water spaniel', 'kuvasz', 'schipperke', 'groenendael', 'malinois', 'briard', 'kelpie', 'komondor', 'old english sheepdog', 'bobtail', 'shetland sheepdog', 'shetland sheep dog', 'shetland', 'collie', 'border collie', 'bouvier des flandres', 'bouviers des flandres', 'rottweiler', 'german shepherd', 'german shepherd dog', 'german police dog', 'alsatian', 'doberman', 'doberman pinscher', 'miniature pinscher', 'greater swiss mountain dog', 'bernese mountain dog', 'appenzeller', 'entlebucher', 'boxer', 'bull mastiff', 'tibetan mastiff', 'french bulldog', 'great dane', 'saint bernard', 'st bernard', 'eskimo dog', 'husky', 'malamute', 'malemute', 'alaskan malamute', 'siberian husky', 'dalmatian', 'coach dog', 'carriage dog', 'affenpinscher', 'monkey pinscher', 'monkey dog', 'basenji', 'pug', 'pug-dog', 'leonberg', 'newfoundland', 'newfoundland dog', 'great pyrenees', 'samoyed', 'samoyede', 'pomeranian', 'chow', 'chow chow', 'keeshond', 'brabancon griffon', 'pembroke', 'pembroke welsh corgi', 'corgi', 'cardigan', 'cardigan welsh corgi', 'corgi', 'toy poodle', 'miniature poodle', 'standard poodle', 'poodle', 'mexican hairless', 'affenpinscher', 'afghan hound', 'airedale terrier', 'akita', 'alaskan malamute', 'american eskimo dog', 'american foxhound', 'american staffordshire terrier', 'american water spaniel', 'anatolian shepherd dog', 'australian cattle dog', 'australian shepherd', 'basset hound', 'bearded collie', 'beauceron', 'belgian malinois', 'belgian sheepdog', 'belgian tervuren', 'bichon frise', 'black and tan coonhound', 'black russian terrier', 'bloodhound', 'bluetick coonhound', 'borzoi', 'boston terrier', 'bouvier des flandres', 'boykin spaniel', 'brittany', 'brussels griffon', 'bull terrier', 'bulldog', 'bullmastiff', 'cairn terrier', 'canaan dog', 'cane corso', 'cardigan welsh corgi', 'cavalier king charles spaniel', 'chinese crested', 'chinese shar-pei', 'chow chow', 'clumber spaniel', 'cocker spaniel', 'corgi', 'dachshund', 'dalmatian', 'dandie dinmont terrier', 'deerhound', 'doberman pinscher', 'dogue de bordeaux', 'english cocker spanie ...

# %%
results
# Out:
# {'Basenji_00963.jpg': ['basenji', 'basenji', 1, 1, 1],
#  'Basenji_00974.jpg': ['basenji', 'basenji', 1, 1, 1],
#  'Basset_hound_01034.jpg': ['basset hound', 'basset, basset hound', 1, 1, 1],
#  'Beagle_01125.jpg': ['beagle', 'beagle', 1, 1, 1],
#  'Beagle_01141.jpg': ['beagle', 'beagle', 1, 1, 1],
#  'Beagle_01170.jpg': ['beagle', 'walker hound, walker foxhound', 0, 1, 1],
#  'Boston_terrier_02259.jpg': ['boston terrier',
#   'boston bull, boston terrier',
#   1,
#   1,
#   1],
#  'Boston_terrier_02285.jpg': ['boston terrier',
#   'boston bull, boston terrier',
#   1,
#   1,
#   1],
#  'Boston_terrier_02303.jpg': ['boston terrier',
#   'boston bull, boston terrier',
#   1,
#   1,
#   1],
#  'Boxer_02426.jpg': ['boxer', 'boxer', 1, 1, 1],
#  'cat_01.jpg': ['cat', 'lynx', 0, 0, 0],
#  'cat_02.jpg': ['cat', 'tabby, tabby cat, cat', 1, 0, 0],
#  'cat_07.jpg': ['cat', 'egyptian cat, cat', 1, 0, 0],
#  'Cocker_spaniel_03750.jpg': ['cocker spaniel',
#   'cocker spaniel, english cocker spaniel, cocker',
#   1,
#   1,
#   1],
#  'Collie_03797.jpg': ['collie', 'collie', 1, 1, 1],
#  'Dalmatian_04017.jpg': ['dalmatian',
#   'dalmatian, coach dog, carriage dog',
#   1,
#   1,
#   1],
#  'Dalmatian_04037.jpg': ['dalmatian',
#   'dalmatian, coach dog, carriage dog',
#   1,
#   1,
#   1],
#  'Dalmatian_04068.jpg': ['dalmatian',
#   'dalmatian, coach dog, carriage dog',
#   1,
#   1,
#   1],
#  'fox_squirrel_01.jpg': ['fox squirrel',
#   'fox squirrel, eastern fox squirrel, sciurus niger',
#   1,
#   0,
#   0],
#  'gecko_02.jpg': ['gecko', 'banded gecko, gecko', 1, 0, 0],
#  'gecko_80.jpg': ['gecko',
#   'tailed frog, bell toad, ribbed toad, tailed toad, ascaphus trui',
#   0,
#   0,
#   0],
#  'German_shepherd_dog_04890.jpg': ['german shepherd dog',
#   'german shepherd, german shepherd dog, german police dog, alsatian',
#   1,
#   1,
#   1],
#  'German_shepherd_dog_04931.jpg': ['german shepherd dog',
#   'german shepherd, german shepherd dog, german police dog, alsatian',
#   1,
#   1,
#   1],
#  'German_shorthaired_pointer_04986.jpg': ['german shorthaired pointer',
#   'german shorthaired pointer',
#   1,
#   1,
#   1],
#  'Golden_retriever_05182.jpg': ['golden retriever',
#   'golden retriever',
#   1,
#   1,
#   1],
#  'Golden_retriever_05195.jpg': ['golden retriever',
#   'golden retriever',
#   1,
#   1,
#   1],
#  'Golden_retriever_05223.jpg': ['golden retriever',
#   'golden retriever',
#   1,
#   1,
#   1],
#  'Golden_retriever_05257.jpg': ['golden retriever',
#   'golden retriever',
#   1,
#   1,
#   1],
#  'Great_dane_05320.jpg': ['great dane', 'great dane', 1, 1, 1],
#  'great_horned_owl_02.jpg': ['great horned owl',
#   'ruffed grouse, partridge, bonasa umbellus',
#   0,
#   0,
#   0],
#  'Great_pyrenees_05367.jpg': ['great pyrenees', 'kuvasz', 0, 1, 1],
#  'Great_pyrenees_05435.jpg': ['great pyrenees', 'great pyrenees', 1, 1, 1],
#  'Miniature_schnauzer_06884.jpg': ['miniature schnauzer',
#   'miniature schnauzer',
#   1,
#   1,
#   1],
#  'polar_bear_04.jpg': ['polar bear',
#   'ice bear, polar bear, ursus maritimus, thalarctos maritimus',
#   1,
#   0,
#   0],
#  'Poodle_07927.jpg': ['poodle', 'standard poodle, poodle', 1, 1, 1],
#  'Poodle_07956.jpg': ['poodle', 'standard poodle, poodle', 1, 1, 1],
#  'Rabbit_002.jpg': ['rabbit',
#   'wood rabbit, cottontail, cottontail rabbit, rabbit',
#   1,
#   0,
#   0],
#  'Saint_bernard_08010.jpg': ['saint bernard',
#   'saint bernard, st bernard',
#   1,
#   1,
#   1],
#  'Saint_bernard_08036.jpg': ['saint bernard',
#   'saint bernard, st bernard',
#   1,
#   1,
#   1],
#  'skunk_029.jpg': ['skunk', 'skunk, polecat, wood pussy', 1, 0, 0]}
